# %%
import pyodbc

# Database connection details
server = 'VWIBSSQLPRD101'
database = 'GHRBI'
username = ''  # Replace with your credentials
password = ''  # Replace with your credentials

# Establish connection
# On Linux the Windows driver name 'SQL Server' is not available.
# Install the Microsoft ODBC driver for SQL Server and use the Linux driver name.
conn_str = (
    "DRIVER={ODBC Driver 18 for SQL Server};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"UID={username};"
    f"PWD={password};"
    "Encrypt=no;"
    "TrustServerCertificate=yes;"
)
conn = pyodbc.connect(conn_str)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 21
#       9 # Establish connection
#      10 # On Linux the Windows driver name 'SQL Server' is not available.
#      11 # Install the Microsoft ODBC driver for SQL Server and use the Linux driver name.
#      12 conn_str = (
#      13     "DRIVER={ODBC Driver 18 for SQL Server};"
#      14     f"SERVER={server};"
#    (...)     19     "TrustServerCertificate=yes;"
#      20 )
# ---> 21 conn = pyodbc.connect(conn_str)
#
# OperationalError: ('HYT00', '[HYT00] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0) (SQLDriverConnect)')

# %%
pip install Office365-REST-Python-Client
# Out:
# Collecting Office365-REST-Python-Client
#   Downloading Office365_REST_Python_Client-2.6.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from Office365-REST-Python-Client) (2.32.5)
# Collecting msal (from Office365-REST-Python-Client)
#   Downloading msal-1.36.0-py3-none-any.whl.metadata (11 kB)
# Collecting pytz (from Office365-REST-Python-Client)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from Office365-REST-Python-Client) (4.15.0)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal->Office365-REST-Python-Client)
#   Downloading pyjwt-2.12.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cryptography<49,>=2.5 (from msal->Office365-REST-Python-Client)
#   Downloading cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: cffi>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography<49,>=2.5->msal->Office365-REST-Python-Client) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->Office365-REST-Python-Client) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->Office365-REST-Python-Client) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->Office365-REST-Python-Client) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->Office365-REST-Python-Client) (2026.2.25)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography<49,>=2.5->msal->Office365-REST-Python-Client) (3.0)
# Downloading Office365_REST_Python_Client-2.6.2-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.8 MB/s  0:00:00
# Downloading msal-1.36.0-py3-none-any.whl (121 kB)
# Downloading cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 21.3 MB/s  0:00:00 eta 0:00:01
# Downloading pyjwt-2.12.1-py3-none-any.whl (29 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Installing collected packages: pytz, PyJWT, cryptography, msal, Office365-REST-Python-Client
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [Office365-REST-Python-Client]EST-Python-Client]
# Successfully installed Office365-REST-Python-Client-2.6.2 PyJWT-2.12.1 cryptography-47.0.0 msal-1.36.0 pytz-2026.1.post1
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
